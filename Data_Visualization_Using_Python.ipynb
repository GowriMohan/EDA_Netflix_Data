# %% [markdown]
# <h1><font color="#BE33FF"><b>Data Visualization</b></font></h1>

# %% [markdown]
# <ul>
# <li>Data visualization is the graphical representation of information and data in a pictorial or graphical format (charts, graphs, and maps).</li>
# <li>Data visualization tools provide an accessible way to see and understand trends, patterns in data, and outliers. </li>
# <li>Data visualization tools and technologies are essential to analyzing massive amounts of information and making data-driven decisions. </li>
# </ul>

# %% [markdown]
# ##### The plots plotted here includes:
# <p><p>
# <dl>
# <dt>1. Lineplot</dt>
# <dt>2. Barplot</dt>
# <dt>3. Countplot</dt>
# <dt>4. Boxplot</dt>
# <dt>5. Histogram</dt>
# <dt>6. Scatterplot</dt>
# <dt>7. Jointplot</dt>
# <dt>8. Pairplot</dt>
# <dt>9. Heatmap</dt>
# <dt>10. Pieplot</dt>
# <dt>11. Subplot</dt>
# </dl>

# %% [markdown]
# pip install matplotlib <br>
# pip install seaborn

# %% [markdown]
# # 1. LINEPLOT
#
# - A line plot is a graphical representation of data that displays data points along a number line.
# - Line plots are commonly used in statistics and data analysis to visualize the relationship between two numerical variables.

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
#Functional magnetic resonance imaging, or fMRI, is a technique for measuring brain activity.

# %%
fmri=sns.load_dataset("fmri")
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
fmri.shape
# Out:
# (1064, 5)

# %%
sns.lineplot(x="timepoint",y="signal",data=fmri)
plt.show()

# %%
event_values=fmri['event'].unique()
event_values
# Out:
# array(['stim', 'cue'], dtype=object)

# %%
sns.lineplot(x="timepoint",y="signal",data=fmri, hue="event")
plt.show()

# %%
sns.lineplot(x="timepoint",y="signal",data=fmri, hue="event", style="event")
plt.show()

# %%
sns.lineplot(x="timepoint",y="signal",data=fmri, hue="event", style="event", markers=True)
plt.show()

# %%
# a=df[['ram','battery_power','px_width','px_height','talk_time','pc','int_memory']]
# plt.figure(figsize=(12,8))
# for i, j in enumerate(a):
#     plt.subplot(3,3, i+1)
#     sns.lineplot(y=df[j],x=df["timepoint"])
# plt.tight_layout()

# %% [markdown]
# # 2. BARPLOT
# - Bar plots are commonly used to visualize data that has been organized into categories, such as the results of a survey.

# %%
import pandas as pd
df= pd.read_csv("imdb.csv")
df.head(5)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
genre=df["Certificate"].unique()
genre
# Out:
# array(['A', 'UA', 'U', 'PG-13', 'R', nan, 'PG', 'G', 'Passed', 'TV-14',
#        '16', 'TV-MA', 'Unrated', 'GP', 'Approved', 'TV-PG', 'U/A'],
#       dtype=object)

# %%
# df_sorted_desc= df.sort_values('IMDB_Rating',ascending=False)
# df_sorted_desc.head()

# %%
plt.figure(figsize=(11,4))
sns.barplot(x="Certificate", y="Meta_score", data=df)
plt.show()

# %%
sns.barplot(x="Meta_score", y="Certificate", data=df, orient="h", order=df.groupby('Certificate')['Meta_score'].mean().sort_values(ascending=False).index)
plt.show()

# %% [markdown]
# # 3. COUNT PLOT

# %%
diamonds =sns.load_dataset("diamonds")
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.countplot(x='cut',data=diamonds, palette='CMRmap')
plt.title("Types of cuts")
plt.show()

# %%
plt.title("Types of cuts based on color ")
sns.countplot(x="cut",hue="color",data=diamonds, palette='YlOrRd')
plt.show()

# %%
cols = ['cut', 'clarity', 'color']
for i in cols:
    if (diamonds[i].nunique())<=25:
        sns.countplot(x=diamonds[i])
        plt.show()

# %% [markdown]
# # 4. BOXPLOT

# %%
num_col= ['carat','depth','table','price', 'x', 'y','z']
plt.figure(figsize=(15, 7))
for i in range(0, len(num_col)):
    plt.subplot(3, 3, i+1)                          # 3 rows, 3 cols
    sns.boxplot(x=diamonds[num_col[i]],orient='h')
    plt.tight_layout()

# %%
health=sns.load_dataset("healthexp")
health.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
sns.boxplot(x="Country",y="Life_Expectancy",data=health)
plt.show()

# %%
titanic=sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.boxplot(x="alive",y="age",data=titanic)
plt.show()

# %%
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(x="sex",y="tip",data=tips,linewidth=3, order=["Female","Male"], hue="smoker")
plt.show()

# %% [markdown]
# # 5. HISTOGRAM
# - Histograms are commonly used to visualize data that is distributed over a continuous range.
# - For e.g., distribution of temperatures over the course of a year

# %%
diamonds["cut"].unique()
# Out:
# ['Ideal', 'Premium', 'Good', 'Very Good', 'Fair']
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
sns.histplot(diamonds["price"])             #displot / histplot both gives histogram
plt.show()

# %%
c=diamonds[['carat','depth','table','price', 'x', 'y','z']]
plt.figure(figsize=(12,8))
for i, j in enumerate(c): 
    plt.subplot(3,3, i+1)           # 3rows, 3 cols
    sns.histplot( diamonds[j], kde = True)
plt.tight_layout()

# %%
sns.displot(diamonds["price"])             #displot
plt.show()

# %%
sns.distplot(diamonds["price"])                    #distplot
plt.show()
# Out:
# C:\Users\Mohan\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.histplot(diamonds["price"], color="green")               #displot
plt.show()

# %%
sns.histplot(diamonds["price"],kde=True, bins=5)              #displot
plt.show()

# %% [markdown]
# # 6. SCATTERPLOT
# - A scatter plot is a graphical representation of data that uses dots or other symbols to show the relationship between two numerical variables.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %%
iris=sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.scatterplot(x="sepal_length", y="petal_length", data=iris)
plt.show()

# %%
sns.scatterplot(x="sepal_length", y="petal_length", data=iris, hue="species")
plt.show()

# %%
sns.scatterplot(x="sepal_length", y="petal_length", data=iris, hue="petal_length")
plt.show()

# %% [markdown]
# # 7. JOINT PLOT
# - A joint plot, also known as a joint distribution plot, is a graphical representation of data that shows the relationship between two numerical variables.
# - It represents the distribution of each variable and also the correlation between the variables

# %%
sns.jointplot(x="sepal_length",y="petal_length",data=iris)
plt.show()

# %%
sns.jointplot(x="sepal_length",y="petal_length",data=iris, color="orange", kind="reg")
plt.show()

# %% [markdown]
# # 8. PAIRPLOT
# - Grid of scatter plots
# - This allows people to easily compare the relationship between different pairs of variables.

# %%
sns.pairplot(iris,hue="species")
plt.show()

# %% [markdown]
# # 9. HEATMAP
# - A heatmap is a graphical representation of data where the values of the data are represented as colors.
# -  Heatmaps can also be used to compare multiple sets of data, or to identify clusters or groups within the data

# %%
glue = sns.load_dataset("glue").pivot("Model", "Task", "Score")
glue.head()
# Out:
# Task         CoLA  MNLI  MRPC  QNLI   QQP   RTE  SST-2  STS-B
# Model
# BERT         60.5  86.7  89.3  92.7  72.1  70.1   94.9   87.6
# BiLSTM       11.6  65.6  81.8  74.6  62.5  57.4   82.8   70.3
# BiLSTM+Attn  18.6  67.6  83.9  74.3  60.1  58.4   83.0   72.8
# BiLSTM+CoVe  18.5  65.4  78.7  70.8  60.6  52.7   81.9   64.4
# BiLSTM+ELMo  32.1  67.2  84.7  75.5  61.1  57.4   89.3   70.3

# %%
sns.heatmap(glue, annot=True, linewidths=1, cmap="Greens")
# Out:
# <AxesSubplot:xlabel='Task', ylabel='Model'>

# %% [markdown]
# # Correlation Map

# %%
# correlation matrix
cor = glue.corr()
cor
# Out:
# Task       CoLA      MNLI      MRPC      QNLI       QQP       RTE     SST-2  \
# Task
# CoLA   1.000000  0.981787  0.960433  0.978301  0.965242  0.938250  0.986446
# MNLI   0.981787  1.000000  0.958480  0.995591  0.991060  0.956564  0.957079
# MRPC   0.960433  0.958480  1.000000  0.969540  0.938840  0.955300  0.965241
# QNLI   0.978301  0.995591  0.969540  1.000000  0.992242  0.952501  0.966674
# QQP    0.965242  0.991060  0.938840  0.992242  1.000000  0.951511  0.946003
# RTE    0.938250  0.956564  0.955300  0.952501  0.951511  1.000000  0.914978
# SST-2  0.986446  0.957079  0.965241  0.966674  0.946003  0.914978  1.000000
# STS-B  0.960484  0.987774  0.979954  0.992825  0.977183  0.957955  0.948825
#
# Task      STS-B
# Task
# CoLA   0.960484
# MNLI   0.987774
# MRPC   0.979954
# QNLI   0.992825
# QQP    0.977183
# RTE    0.957955
# SST-2  0.948825
# STS-B  1.000000

# %%
# plotting correlations on a heatmap
# figure size
plt.figure(figsize=(6,4))
# heatmap
sns.heatmap(cor, cmap="YlGnBu", annot=True)
plt.show()

# %%
#PiYG, #coolwarm # BuPu

# %% [markdown]
# # 10. PIE PLOT
# - Pie plots are useful for showing the relative proportions of the different data points in a dataset.

# %%
# declaring data
data = [44, 45, 40, 41, 39]
keys = ['Group A', 'Group B', 'Group C', 'Group D', 'Group E']
  
explode = [0, 0.1, 0, 0, 0]
palette_color = sns.color_palette('bright')
  
plt.pie(data, labels=keys, colors=palette_color,
        explode=explode, autopct='%.0f%%')

plt.show()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
labels=['Male','Female']
plt.figure(figsize=(5,5))
color=sns.color_palette("Set2")
tips['sex'].value_counts().plot(kind="pie",autopct='%.1f%%',labels=labels,colors=color,figsize=(4,4))
plt.ylabel('Sex')
plt.show()

# %% [markdown]
# # 11. SUBPLOTS

# %%
import numpy as np
  
# making subplots objects
fig, ax = plt.subplots(2, 2)
  
# create data
x = np.linspace(0, 10, 1000)
  
# draw graph
ax[0, 1].plot(x, np.sin(x), 'r-.')
ax[0, 0].plot(x, np.cos(x), 'g--')
ax[1, 0].plot(x, np.tan(x), 'y-')
ax[1, 1].plot(x, np.sinc(x), 'c.-')
  
plt.show()
